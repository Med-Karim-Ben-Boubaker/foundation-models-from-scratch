# %%
import torch
from torch.utils.data import Dataset
from typing import List, Dict, Any
import os
import sys

project_root = os.path.abspath('..')
if project_root not in sys.path:
    sys.path.insert(0, project_root)
    

class InstructFineTuningDataset(Dataset):
    def __init__(self, examples: List[Dict[str, Any]], tokenizer, max_length: int, stride: int = 0):
        self.input_sequences: List[torch.Tensor] = []
        self.target_sequences: List[torch.Tensor] = []
        self.loss_masks: List[torch.Tensor] = []
        
        print(f"Initializing InstructFineTuningDataset with {len(examples)} examples")
        
        for example in examples:
            prompt = f"Instruction:\n{example['instruction']}\n\nInput:\n{example['input']}\n\nResponse:\n"
            full_sequence = prompt + example["output"]
            prompt_tokens = tokenizer.encode(prompt, allowed_special={"<|endoftext|>"})
            full_tokens = tokenizer.encode(full_sequence, allowed_special={"<|endoftext|>"})
            
            if len(full_tokens) > max_length:
                print(f"Sequence too long ({len(full_tokens)} > {max_length}), skipping")
                continue
            
            loss_mask = [0] * len(prompt_tokens) + [1] * (len(full_tokens) - len(prompt_tokens))
            
            self.input_sequences.append(torch.tensor(prompt_tokens, dtype=torch.long))
            self.target_sequences.append(torch.tensor(full_tokens, dtype=torch.long))
            self.loss_masks.append(torch.tensor(loss_mask, dtype=torch.bool))
        
        print(f"Created {len(self.input_sequences)} training examples")
    
    def __len__(self) -> int:
        return len(self.input_sequences)
    
    def __getitem__(self, idx: int) -> tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
        return (
            self.input_sequences[idx],
            self.target_sequences[idx], 
            self.loss_masks[idx]
        )

# %%
import json
from src.data.tokenizer import get_tokenizer

tokenizer = get_tokenizer("gpt2")
alpaca_data = json.load(open("../data/alpaca_data.json"))
instruct_finetuning_dataset = InstructFineTuningDataset(alpaca_data, tokenizer, max_length=256, stride=0)
# Out:
# Initializing InstructFineTuningDataset with 52002 examples
# Sequence too long (290 > 256), skipping
# Sequence too long (322 > 256), skipping
# Sequence too long (257 > 256), skipping
# Sequence too long (264 > 256), skipping
# Sequence too long (263 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (409 > 256), skipping
# Sequence too long (275 > 256), skipping
# Sequence too long (410 > 256), skipping
# Sequence too long (320 > 256), skipping
# Sequence too long (293 > 256), skipping
# Sequence too long (309 > 256), skipping
# Sequence too long (284 > 256), skipping
# Sequence too long (292 > 256), skipping
# Sequence too long (264 > 256), skipping
# Sequence too long (461 > 256), skipping
# Sequence too long (361 > 256), skipping
# Sequence too long (264 > 256), skipping
# Sequence too long (292 > 256), skipping
# Sequence too long (276 > 256), skipping
# Sequence too long (350 > 256), skipping
# Sequence too long (295 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (295 > 256), skipping
# Sequence too long (445 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (276 > 256), skipping
# Sequence too long (306 > 256), skipping
# Sequence too long (320 > 256), skipping
# Sequence too long (377 > 256), skipping
# Sequence too long (347 > 256), skipping
# Sequence too long (274 > 256), skipping
# Sequence too long (277 > 256), skipping
# Sequence too long (270 > 256), skipping
# Sequence too long (318 > 256), skipping
# Sequence too long (280 > 256), skipping
# Sequence too long (307 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (413 > 256), skipping
# Sequence too long (258 > 256), skipping
# Sequence too long (261 > 256), skipping
# Sequence too long (287 > 256), skipping
# Sequence too long (459 > 256), skipping
# Sequence too long (266 > 256), skipping
# Sequence too long (267 > 256), skipping
# Sequence too long (261 > 256), skipping
# Sequence too long (313 > 256), skipping
# Sequence too long (270 > 256), skipping
# Sequence too long (270 > 256), skipping
# Sequence too long (277 > 256), skipping
# Sequence too long (277 > 256), skipping
# Sequence too long (301 > 256), skipping
# Sequence too long (276 > 256), skipping
# Sequence too long (348 > 256), skipping
# Sequence too long (415 > 256), skipping
# Sequence too long (283 > 256), skipping
# Sequence too long (279 > 256), skipping
# Sequence too long (285 > 256), skipping
# Sequence too long (272 > 256), skipping
# Sequence too long (285 > 256), skipping
# Sequence too long (311 > 256), skipping
# Sequence too long (388 > 256), skipping
# Sequence too long (285 > 256), skipping
# Sequence too long (313 > 256), skipping
# Sequence too long (497 > 256), skipping
# Sequence too long (416 > 256), skipping
# Sequence too long (403 > 256), skipping
# Sequence too long (432 > 256), skipping
# Sequence too long (629 > 256), skipping
# Sequence too long (428 > 256), skipping
# Sequence too long (278 > 256), skipping
# Sequence too long (317 > 256), skipping
# Sequence too long (339 > 256), skipping
# Sequence too long (343 > 256), skipping
# Sequence too long (329 > 256), skipping
# Sequence too long (276 > 256), skipping
# Sequence too long (326 > 256), skipping
# Sequence too long (267 > 256), skipping
# Sequence too long (260 > 256), skipping
# Sequence too long (343 > 256), skipping
# Sequence too long (264 > 256), skipping
# Sequence too long (345 > 256), skipping
# Sequence too long (294 > 256), skipping
# Sequence too long (306 > 256), skipping
# Sequence too long (284 > 256), skipping
# Sequence too long (342 > 256), skipping
# Sequence too long (269 > 256), skipping
# Sequence too long (265 > 256), skipping
# Sequence too long (286 > 256), skipping
# Sequence too long (286 > 256), skipping
# Sequence too long (294 > 256), skipping
# Sequence too long (263 > 256), skipping
# Sequence too long (585 > 256), skipping
# Sequence too long (266 > 256), skipping
# Sequence too long (290 > 256), skipping
# Sequence too long (277 > 256), skipping
# Sequence too long (357 > 256), skipping
# Sequence too long (354 > 256), skipping
# Sequence too long (362 > 256), skipping
# Sequence too long (258 > 256), skipping
# Sequence too long (267 > 256), skipping
# Sequence too long (278 > 256), skipping
# Sequence too long (265 > 256), skipping
# Sequence too long (303 > 256), skipping
# Sequence too long (536 > 256), skipping
# Sequence too long (301 > 256), skipping
# Sequence too long (259 > 256), skipping
# Sequence too long (300 > 256), skipping
# Sequence too long (364 > 256), skipping
# Sequence too long (524 > 256), skipping
# Sequence too long (413 > 256), skipping
# Sequence too long (290 > 256), skipping
# Sequence too long (347 > 256), skipping
# Sequence too long (259 > 256), skipping
# Sequence too long (277 > 256), skipping
# Sequence too long (267 > 256), skipping
# Sequence too long (335 > 256), skipping
# Sequence too long (275 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (310 > 256), skipping
# Sequence too long (302 > 256), skipping
# Sequence too long (375 > 256), skipping
# Sequence too long (595 > 256), skipping
# Sequence too long (1013 > 256), skipping
# Sequence too long (258 > 256), skipping
# Sequence too long (279 > 256), skipping
# Sequence too long (502 > 256), skipping
# Sequence too long (375 > 256), skipping
# Sequence too long (385 > 256), skipping
# Sequence too long (267 > 256), skipping
# Sequence too long (302 > 256), skipping
# Sequence too long (292 > 256), skipping
# Sequence too long (317 > 256), skipping
# Sequence too long (549 > 256), skipping
# Sequence too long (276 > 256), skipping
# Sequence too long (626 > 256), skipping
# Sequence too long (369 > 256), skipping
# Sequence too long (299 > 256), skipping
# Sequence too long (382 > 256), skipping
# Sequence too long (387 > 256), skipping
# Sequence too long (300 > 256), skipping
# Sequence too long (273 > 256), skipping
# Sequence too long (295 > 256), skipping
# Sequence too long (406 > 256), skipping
# Sequence too long (417 > 256), skipping
# Sequence too long (293 > 256), skipping
# Sequence too long (310 > 256), skipping
# Sequence too long (692 > 256), skipping
# Sequence too long (398 > 256), skipping
# Sequence too long (274 > 256), skipping
# Sequence too long (318 > 256), skipping
# Sequence too long (268 > 256), skipping
# Sequence too long (294 > 256), skipping
# Sequence too long (258 > 256), skipping
# Sequence too long (269 > 256), skipping
# Sequence too long (346 > 256), skipping
# Sequence too long (384 > 256), skipping
# Sequence too long (487 > 256), skipping
# Sequence too long (291 > 256), skipping
# Sequence too long (352 > 256), skipping
# Sequence too long (269 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (268 > 256), skipping
# Sequence too long (324 > 256), skipping
# Sequence too long (269 > 256), skipping
# Sequence too long (572 > 256), skipping
# Sequence too long (269 > 256), skipping
# Sequence too long (270 > 256), skipping
# Sequence too long (467 > 256), skipping
# Sequence too long (480 > 256), skipping
# Sequence too long (278 > 256), skipping
# Sequence too long (340 > 256), skipping
# Sequence too long (264 > 256), skipping
# Sequence too long (276 > 256), skipping
# Sequence too long (637 > 256), skipping
# Sequence too long (276 > 256), skipping
# Sequence too long (261 > 256), skipping
# Sequence too long (313 > 256), skipping
# Sequence too long (264 > 256), skipping
# Sequence too long (270 > 256), skipping
# Sequence too long (263 > 256), skipping
# Sequence too long (298 > 256), skipping
# Sequence too long (411 > 256), skipping
# Sequence too long (277 > 256), skipping
# Sequence too long (529 > 256), skipping
# Sequence too long (569 > 256), skipping
# Sequence too long (454 > 256), skipping
# Sequence too long (322 > 256), skipping
# Sequence too long (399 > 256), skipping
# Sequence too long (305 > 256), skipping
# Sequence too long (339 > 256), skipping
# Sequence too long (277 > 256), skipping
# Sequence too long (356 > 256), skipping
# Sequence too long (322 > 256), skipping
# Sequence too long (413 > 256), skipping
# Sequence too long (278 > 256), skipping
# Sequence too long (270 > 256), skipping
# Sequence too long (338 > 256), skipping
# Sequence too long (410 > 256), skipping
# Sequence too long (465 > 256), skipping
# Sequence too long (471 > 256), skipping
# Sequence too long (506 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (295 > 256), skipping
# Sequence too long (279 > 256), skipping
# Sequence too long (288 > 256), skipping
# Sequence too long (284 > 256), skipping
# Sequence too long (316 > 256), skipping
# Sequence too long (283 > 256), skipping
# Sequence too long (271 > 256), skipping
# Sequence too long (301 > 256), skipping
# Sequence too long (272 > 256), skipping
# Sequence too long (311 > 256), skipping
# Sequence too long (268 > 256), skipping
# Sequence too long (636 > 256), skipping
# Sequence too long (350 > 256), skipping
# Sequence too long (346 > 256), skipping
# Sequence too long (261 > 256), skipping
# Sequence too long (275 > 256), skipping
# Sequence too long (334 > 256), skipping
# Sequence too long (276 > 256), skipping
# Sequence too long (518 > 256), skipping
# Sequence too long (304 > 256), skipping
# Sequence too long (299 > 256), skipping
# Sequence too long (279 > 256), skipping
# Sequence too long (306 > 256), skipping
# Sequence too long (276 > 256), skipping
# Sequence too long (278 > 256), skipping
# Sequence too long (290 > 256), skipping
# Sequence too long (523 > 256), skipping
# Sequence too long (294 > 256), skipping
# Sequence too long (567 > 256), skipping
# Sequence too long (296 > 256), skipping
# Sequence too long (306 > 256), skipping
# Sequence too long (371 > 256), skipping
# Sequence too long (397 > 256), skipping
# Sequence too long (329 > 256), skipping
# Sequence too long (298 > 256), skipping
# Sequence too long (313 > 256), skipping
# Sequence too long (340 > 256), skipping
# Sequence too long (320 > 256), skipping
# Sequence too long (264 > 256), skipping
# Sequence too long (471 > 256), skipping
# Sequence too long (296 > 256), skipping
# Sequence too long (443 > 256), skipping
# Sequence too long (283 > 256), skipping
# Sequence too long (560 > 256), skipping
# Sequence too long (286 > 256), skipping
# Sequence too long (291 > 256), skipping
# Sequence too long (377 > 256), skipping
# Sequence too long (270 > 256), skipping
# Sequence too long (338 > 256), skipping
# Sequence too long (268 > 256), skipping
# Sequence too long (268 > 256), skipping
# Sequence too long (257 > 256), skipping
# Sequence too long (272 > 256), skipping
# Sequence too long (344 > 256), skipping
# Sequence too long (352 > 256), skipping
# Sequence too long (432 > 256), skipping
# Sequence too long (273 > 256), skipping
# Sequence too long (287 > 256), skipping
# Sequence too long (503 > 256), skipping
# Sequence too long (291 > 256), skipping
# Sequence too long (286 > 256), skipping
# Sequence too long (377 > 256), skipping
# Sequence too long (263 > 256), skipping
# Sequence too long (282 > 256), skipping
# Sequence too long (322 > 256), skipping
# Sequence too long (328 > 256), skipping
# Sequence too long (367 > 256), skipping
# Sequence too long (305 > 256), skipping
# Sequence too long (312 > 256), skipping
# Sequence too long (303 > 256), skipping
# Sequence too long (290 > 256), skipping
# Sequence too long (291 > 256), skipping
# Sequence too long (409 > 256), skipping
# Sequence too long (683 > 256), skipping
# Sequence too long (494 > 256), skipping
# Sequence too long (259 > 256), skipping
# Sequence too long (591 > 256), skipping
# Sequence too long (326 > 256), skipping
# Sequence too long (364 > 256), skipping
# Sequence too long (359 > 256), skipping
# Sequence too long (295 > 256), skipping
# Sequence too long (354 > 256), skipping
# Sequence too long (307 > 256), skipping
# Sequence too long (287 > 256), skipping
# Sequence too long (275 > 256), skipping
# Sequence too long (292 > 256), skipping
# Sequence too long (317 > 256), skipping
# Sequence too long (325 > 256), skipping
# Sequence too long (260 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (777 > 256), skipping
# Sequence too long (353 > 256), skipping
# Sequence too long (514 > 256), skipping
# Sequence too long (382 > 256), skipping
# Sequence too long (269 > 256), skipping
# Sequence too long (257 > 256), skipping
# Sequence too long (344 > 256), skipping
# Sequence too long (300 > 256), skipping
# Sequence too long (444 > 256), skipping
# Sequence too long (336 > 256), skipping
# Sequence too long (257 > 256), skipping
# Sequence too long (315 > 256), skipping
# Sequence too long (302 > 256), skipping
# Sequence too long (283 > 256), skipping
# Sequence too long (385 > 256), skipping
# Sequence too long (260 > 256), skipping
# Sequence too long (270 > 256), skipping
# Sequence too long (283 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (295 > 256), skipping
# Sequence too long (689 > 256), skipping
# Sequence too long (258 > 256), skipping
# Sequence too long (261 > 256), skipping
# Sequence too long (274 > 256), skipping
# Sequence too long (296 > 256), skipping
# Sequence too long (266 > 256), skipping
# Sequence too long (292 > 256), skipping
# Sequence too long (390 > 256), skipping
# Sequence too long (292 > 256), skipping
# Sequence too long (325 > 256), skipping
# Sequence too long (294 > 256), skipping
# Sequence too long (385 > 256), skipping
# Sequence too long (270 > 256), skipping
# Sequence too long (284 > 256), skipping
# Sequence too long (304 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (329 > 256), skipping
# Sequence too long (272 > 256), skipping
# Sequence too long (259 > 256), skipping
# Sequence too long (332 > 256), skipping
# Sequence too long (258 > 256), skipping
# Sequence too long (316 > 256), skipping
# Sequence too long (290 > 256), skipping
# Sequence too long (300 > 256), skipping
# Sequence too long (298 > 256), skipping
# Sequence too long (263 > 256), skipping
# Sequence too long (258 > 256), skipping
# Sequence too long (275 > 256), skipping
# Sequence too long (297 > 256), skipping
# Sequence too long (359 > 256), skipping
# Sequence too long (275 > 256), skipping
# Sequence too long (433 > 256), skipping
# Sequence too long (433 > 256), skipping
# Sequence too long (280 > 256), skipping
# Sequence too long (318 > 256), skipping
# Sequence too long (261 > 256), skipping
# Sequence too long (686 > 256), skipping
# Sequence too long (539 > 256), skipping
# Sequence too long (360 > 256), skipping
# Sequence too long (303 > 256), skipping
# Sequence too long (303 > 256), skipping
# Sequence too long (414 > 256), skipping
# Sequence too long (322 > 256), skipping
# Sequence too long (280 > 256), skipping
# Sequence too long (298 > 256), skipping
# Sequence too long (277 > 256), skipping
# Sequence too long (277 > 256), skipping
# Sequence too long (382 > 256), skipping
# Sequence too long (270 > 256), skipping
# Sequence too long (381 > 256), skipping
# Sequence too long (693 > 256), skipping
# Sequence too long (398 > 256), skipping
# Sequence too long (264 > 256), skipping
# Sequence too long (300 > 256), skipping
# Sequence too long (359 > 256), skipping
# Sequence too long (290 > 256), skipping
# Sequence too long (260 > 256), skipping
# Sequence too long (267 > 256), skipping
# Sequence too long (333 > 256), skipping
# Sequence too long (327 > 256), skipping
# Sequence too long (651 > 256), skipping
# Sequence too long (475 > 256), skipping
# Sequence too long (319 > 256), skipping
# Sequence too long (318 > 256), skipping
# Sequence too long (282 > 256), skipping
# Sequence too long (311 > 256), skipping
# Sequence too long (291 > 256), skipping
# Sequence too long (409 > 256), skipping
# Sequence too long (272 > 256), skipping
# Sequence too long (989 > 256), skipping
# Sequence too long (261 > 256), skipping
# Sequence too long (293 > 256), skipping
# Sequence too long (282 > 256), skipping
# Sequence too long (266 > 256), skipping
# Sequence too long (276 > 256), skipping
# Sequence too long (333 > 256), skipping
# Sequence too long (389 > 256), skipping
# Sequence too long (368 > 256), skipping
# Sequence too long (349 > 256), skipping
# Sequence too long (330 > 256), skipping
# Sequence too long (587 > 256), skipping
# Sequence too long (272 > 256), skipping
# Sequence too long (368 > 256), skipping
# Sequence too long (348 > 256), skipping
# Sequence too long (321 > 256), skipping
# Sequence too long (304 > 256), skipping
# Sequence too long (270 > 256), skipping
# Sequence too long (295 > 256), skipping
# Sequence too long (260 > 256), skipping
# Sequence too long (270 > 256), skipping
# Sequence too long (279 > 256), skipping
# Sequence too long (283 > 256), skipping
# Sequence too long (311 > 256), skipping
# Sequence too long (301 > 256), skipping
# Sequence too long (369 > 256), skipping
# Sequence too long (338 > 256), skipping
# Sequence too long (272 > 256), skipping
# Sequence too long (257 > 256), skipping
# Sequence too long (324 > 256), skipping
# Sequence too long (319 > 256), skipping
# Sequence too long (315 > 256), skipping
# Sequence too long (293 > 256), skipping
# Sequence too long (335 > 256), skipping
# Sequence too long (430 > 256), skipping
# Sequence too long (421 > 256), skipping
# Sequence too long (265 > 256), skipping
# Sequence too long (345 > 256), skipping
# Sequence too long (416 > 256), skipping
# Sequence too long (277 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (291 > 256), skipping
# Sequence too long (267 > 256), skipping
# Sequence too long (341 > 256), skipping
# Sequence too long (271 > 256), skipping
# Sequence too long (298 > 256), skipping
# Sequence too long (275 > 256), skipping
# Sequence too long (268 > 256), skipping
# Sequence too long (343 > 256), skipping
# Sequence too long (385 > 256), skipping
# Sequence too long (257 > 256), skipping
# Sequence too long (257 > 256), skipping
# Sequence too long (278 > 256), skipping
# Sequence too long (310 > 256), skipping
# Sequence too long (269 > 256), skipping
# Sequence too long (427 > 256), skipping
# Sequence too long (261 > 256), skipping
# Sequence too long (333 > 256), skipping
# Sequence too long (265 > 256), skipping
# Sequence too long (320 > 256), skipping
# Sequence too long (305 > 256), skipping
# Sequence too long (579 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (301 > 256), skipping
# Sequence too long (272 > 256), skipping
# Sequence too long (323 > 256), skipping
# Sequence too long (261 > 256), skipping
# Sequence too long (279 > 256), skipping
# Sequence too long (297 > 256), skipping
# Sequence too long (277 > 256), skipping
# Sequence too long (312 > 256), skipping
# Sequence too long (364 > 256), skipping
# Sequence too long (358 > 256), skipping
# Sequence too long (261 > 256), skipping
# Sequence too long (276 > 256), skipping
# Sequence too long (261 > 256), skipping
# Sequence too long (263 > 256), skipping
# Sequence too long (551 > 256), skipping
# Sequence too long (314 > 256), skipping
# Sequence too long (404 > 256), skipping
# Sequence too long (392 > 256), skipping
# Sequence too long (339 > 256), skipping
# Sequence too long (258 > 256), skipping
# Sequence too long (263 > 256), skipping
# Sequence too long (312 > 256), skipping
# Sequence too long (259 > 256), skipping
# Sequence too long (289 > 256), skipping
# Sequence too long (291 > 256), skipping
# Sequence too long (290 > 256), skipping
# Sequence too long (298 > 256), skipping
# Sequence too long (287 > 256), skipping
# Sequence too long (321 > 256), skipping
# Sequence too long (280 > 256), skipping
# Sequence too long (276 > 256), skipping
# Sequence too long (306 > 256), skipping
# Sequence too long (261 > 256), skipping
# Sequence too long (1493 > 256), skipping
# Sequence too long (276 > 256), skipping
# Sequence too long (283 > 256), skipping
# Sequence too long (364 > 256), skipping
# Sequence too long (281 > 256), skipping
# Sequence too long (303 > 256), skipping
# Sequence too long (289 > 256), skipping
# Sequence too long (318 > 256), skipping
# Sequence too long (325 > 256), skipping
# Sequence too long (310 > 256), skipping
# Sequence too long (324 > 256), skipping
# Sequence too long (591 > 256), skipping
# Sequence too long (269 > 256), skipping
# Sequence too long (268 > 256), skipping
# Sequence too long (291 > 256), skipping
# Sequence too long (293 > 256), skipping
# Sequence too long (265 > 256), skipping
# Sequence too long (391 > 256), skipping
# Sequence too long (327 > 256), skipping
# Sequence too long (277 > 256), skipping
# Sequence too long (315 > 256), skipping
# Sequence too long (282 > 256), skipping
# Sequence too long (378 > 256), skipping
# Sequence too long (353 > 256), skipping
# Sequence too long (349 > 256), skipping
# Sequence too long (258 > 256), skipping
# Sequence too long (290 > 256), skipping
# Sequence too long (316 > 256), skipping
# Sequence too long (407 > 256), skipping
# Sequence too long (548 > 256), skipping
# Sequence too long (274 > 256), skipping
# Sequence too long (314 > 256), skipping
# Sequence too long (260 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (266 > 256), skipping
# Sequence too long (338 > 256), skipping
# Sequence too long (339 > 256), skipping
# Sequence too long (303 > 256), skipping
# Sequence too long (285 > 256), skipping
# Sequence too long (293 > 256), skipping
# Sequence too long (309 > 256), skipping
# Sequence too long (308 > 256), skipping
# Sequence too long (415 > 256), skipping
# Sequence too long (322 > 256), skipping
# Sequence too long (480 > 256), skipping
# Sequence too long (327 > 256), skipping
# Sequence too long (402 > 256), skipping
# Sequence too long (264 > 256), skipping
# Sequence too long (371 > 256), skipping
# Sequence too long (594 > 256), skipping
# Sequence too long (282 > 256), skipping
# Sequence too long (306 > 256), skipping
# Sequence too long (407 > 256), skipping
# Sequence too long (275 > 256), skipping
# Sequence too long (343 > 256), skipping
# Sequence too long (297 > 256), skipping
# Sequence too long (290 > 256), skipping
# Sequence too long (268 > 256), skipping
# Sequence too long (306 > 256), skipping
# Sequence too long (517 > 256), skipping
# Sequence too long (267 > 256), skipping
# Sequence too long (265 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (300 > 256), skipping
# Sequence too long (292 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (396 > 256), skipping
# Sequence too long (297 > 256), skipping
# Sequence too long (456 > 256), skipping
# Sequence too long (294 > 256), skipping
# Sequence too long (575 > 256), skipping
# Sequence too long (521 > 256), skipping
# Sequence too long (334 > 256), skipping
# Sequence too long (268 > 256), skipping
# Sequence too long (344 > 256), skipping
# Sequence too long (289 > 256), skipping
# Sequence too long (419 > 256), skipping
# Sequence too long (307 > 256), skipping
# Sequence too long (285 > 256), skipping
# Sequence too long (435 > 256), skipping
# Sequence too long (395 > 256), skipping
# Sequence too long (269 > 256), skipping
# Sequence too long (299 > 256), skipping
# Sequence too long (452 > 256), skipping
# Sequence too long (450 > 256), skipping
# Sequence too long (390 > 256), skipping
# Sequence too long (454 > 256), skipping
# Sequence too long (332 > 256), skipping
# Sequence too long (312 > 256), skipping
# Sequence too long (360 > 256), skipping
# Sequence too long (285 > 256), skipping
# Sequence too long (360 > 256), skipping
# Sequence too long (267 > 256), skipping
# Sequence too long (339 > 256), skipping
# Sequence too long (359 > 256), skipping
# Sequence too long (285 > 256), skipping
# Sequence too long (300 > 256), skipping
# Sequence too long (323 > 256), skipping
# Sequence too long (264 > 256), skipping
# Sequence too long (304 > 256), skipping
# Sequence too long (486 > 256), skipping
# Sequence too long (328 > 256), skipping
# Sequence too long (307 > 256), skipping
# Sequence too long (432 > 256), skipping
# Sequence too long (278 > 256), skipping
# Sequence too long (449 > 256), skipping
# Sequence too long (418 > 256), skipping
# Sequence too long (292 > 256), skipping
# Sequence too long (463 > 256), skipping
# Sequence too long (428 > 256), skipping
# Sequence too long (344 > 256), skipping
# Sequence too long (346 > 256), skipping
# Sequence too long (287 > 256), skipping
# Sequence too long (303 > 256), skipping
# Sequence too long (277 > 256), skipping
# Sequence too long (274 > 256), skipping
# Sequence too long (315 > 256), skipping
# Sequence too long (453 > 256), skipping
# Sequence too long (323 > 256), skipping
# Sequence too long (397 > 256), skipping
# Sequence too long (453 > 256), skipping
# Sequence too long (320 > 256), skipping
# Sequence too long (282 > 256), skipping
# Sequence too long (297 > 256), skipping
# Sequence too long (267 > 256), skipping
# Sequence too long (276 > 256), skipping
# Sequence too long (317 > 256), skipping
# Sequence too long (353 > 256), skipping
# Sequence too long (270 > 256), skipping
# Sequence too long (329 > 256), skipping
# Sequence too long (468 > 256), skipping
# Sequence too long (272 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (313 > 256), skipping
# Sequence too long (412 > 256), skipping
# Sequence too long (264 > 256), skipping
# Sequence too long (274 > 256), skipping
# Sequence too long (684 > 256), skipping
# Sequence too long (341 > 256), skipping
# Sequence too long (294 > 256), skipping
# Sequence too long (477 > 256), skipping
# Sequence too long (514 > 256), skipping
# Sequence too long (258 > 256), skipping
# Sequence too long (286 > 256), skipping
# Sequence too long (361 > 256), skipping
# Sequence too long (281 > 256), skipping
# Sequence too long (311 > 256), skipping
# Sequence too long (269 > 256), skipping
# Sequence too long (265 > 256), skipping
# Sequence too long (362 > 256), skipping
# Sequence too long (293 > 256), skipping
# Sequence too long (333 > 256), skipping
# Sequence too long (277 > 256), skipping
# Sequence too long (342 > 256), skipping
# Sequence too long (284 > 256), skipping
# Sequence too long (264 > 256), skipping
# Sequence too long (266 > 256), skipping
# Sequence too long (284 > 256), skipping
# Sequence too long (393 > 256), skipping
# Sequence too long (264 > 256), skipping
# Sequence too long (329 > 256), skipping
# Sequence too long (342 > 256), skipping
# Sequence too long (442 > 256), skipping
# Sequence too long (360 > 256), skipping
# Sequence too long (264 > 256), skipping
# Sequence too long (274 > 256), skipping
# Sequence too long (354 > 256), skipping
# Sequence too long (287 > 256), skipping
# Sequence too long (316 > 256), skipping
# Sequence too long (328 > 256), skipping
# Sequence too long (359 > 256), skipping
# Sequence too long (524 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (443 > 256), skipping
# Sequence too long (666 > 256), skipping
# Sequence too long (308 > 256), skipping
# Sequence too long (335 > 256), skipping
# Sequence too long (373 > 256), skipping
# Sequence too long (331 > 256), skipping
# Sequence too long (443 > 256), skipping
# Sequence too long (260 > 256), skipping
# Sequence too long (317 > 256), skipping
# Sequence too long (338 > 256), skipping
# Sequence too long (308 > 256), skipping
# Sequence too long (362 > 256), skipping
# Sequence too long (309 > 256), skipping
# Sequence too long (387 > 256), skipping
# Sequence too long (274 > 256), skipping
# Sequence too long (274 > 256), skipping
# Sequence too long (406 > 256), skipping
# Sequence too long (340 > 256), skipping
# Sequence too long (360 > 256), skipping
# Sequence too long (382 > 256), skipping
# Sequence too long (283 > 256), skipping
# Sequence too long (259 > 256), skipping
# Sequence too long (402 > 256), skipping
# Sequence too long (387 > 256), skipping
# Sequence too long (327 > 256), skipping
# Sequence too long (277 > 256), skipping
# Sequence too long (281 > 256), skipping
# Sequence too long (307 > 256), skipping
# Sequence too long (529 > 256), skipping
# Sequence too long (443 > 256), skipping
# Sequence too long (646 > 256), skipping
# Sequence too long (265 > 256), skipping
# Sequence too long (435 > 256), skipping
# Sequence too long (286 > 256), skipping
# Sequence too long (336 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (547 > 256), skipping
# Sequence too long (286 > 256), skipping
# Sequence too long (257 > 256), skipping
# Sequence too long (372 > 256), skipping
# Sequence too long (284 > 256), skipping
# Sequence too long (304 > 256), skipping
# Sequence too long (452 > 256), skipping
# Sequence too long (302 > 256), skipping
# Sequence too long (277 > 256), skipping
# Sequence too long (362 > 256), skipping
# Sequence too long (259 > 256), skipping
# Sequence too long (324 > 256), skipping
# Sequence too long (475 > 256), skipping
# Sequence too long (300 > 256), skipping
# Sequence too long (321 > 256), skipping
# Sequence too long (349 > 256), skipping
# Sequence too long (422 > 256), skipping
# Sequence too long (294 > 256), skipping
# Sequence too long (334 > 256), skipping
# Sequence too long (294 > 256), skipping
# Sequence too long (346 > 256), skipping
# Sequence too long (305 > 256), skipping
# Sequence too long (332 > 256), skipping
# Sequence too long (313 > 256), skipping
# Sequence too long (369 > 256), skipping
# Sequence too long (325 > 256), skipping
# Sequence too long (296 > 256), skipping
# Sequence too long (401 > 256), skipping
# Sequence too long (280 > 256), skipping
# Sequence too long (300 > 256), skipping
# Sequence too long (314 > 256), skipping
# Sequence too long (311 > 256), skipping
# Sequence too long (265 > 256), skipping
# Sequence too long (259 > 256), skipping
# Sequence too long (340 > 256), skipping
# Sequence too long (265 > 256), skipping
# Sequence too long (281 > 256), skipping
# Sequence too long (266 > 256), skipping
# Sequence too long (270 > 256), skipping
# Sequence too long (344 > 256), skipping
# Sequence too long (344 > 256), skipping
# Sequence too long (405 > 256), skipping
# Sequence too long (349 > 256), skipping
# Sequence too long (378 > 256), skipping
# Sequence too long (263 > 256), skipping
# Sequence too long (277 > 256), skipping
# Sequence too long (437 > 256), skipping
# Sequence too long (312 > 256), skipping
# Sequence too long (368 > 256), skipping
# Sequence too long (275 > 256), skipping
# Sequence too long (284 > 256), skipping
# Sequence too long (314 > 256), skipping
# Sequence too long (286 > 256), skipping
# Sequence too long (258 > 256), skipping
# Sequence too long (267 > 256), skipping
# Sequence too long (280 > 256), skipping
# Sequence too long (431 > 256), skipping
# Sequence too long (268 > 256), skipping
# Sequence too long (306 > 256), skipping
# Sequence too long (351 > 256), skipping
# Sequence too long (370 > 256), skipping
# Sequence too long (260 > 256), skipping
# Sequence too long (335 > 256), skipping
# Sequence too long (305 > 256), skipping
# Sequence too long (260 > 256), skipping
# Sequence too long (299 > 256), skipping
# Sequence too long (289 > 256), skipping
# Sequence too long (280 > 256), skipping
# Sequence too long (503 > 256), skipping
# Sequence too long (400 > 256), skipping
# Sequence too long (263 > 256), skipping
# Sequence too long (388 > 256), skipping
# Sequence too long (341 > 256), skipping
# Sequence too long (257 > 256), skipping
# Sequence too long (337 > 256), skipping
# Sequence too long (328 > 256), skipping
# Sequence too long (261 > 256), skipping
# Sequence too long (263 > 256), skipping
# Sequence too long (447 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (266 > 256), skipping
# Sequence too long (301 > 256), skipping
# Sequence too long (607 > 256), skipping
# Sequence too long (342 > 256), skipping
# Sequence too long (389 > 256), skipping
# Sequence too long (325 > 256), skipping
# Sequence too long (341 > 256), skipping
# Sequence too long (375 > 256), skipping
# Sequence too long (273 > 256), skipping
# Sequence too long (275 > 256), skipping
# Sequence too long (320 > 256), skipping
# Sequence too long (283 > 256), skipping
# Sequence too long (424 > 256), skipping
# Sequence too long (299 > 256), skipping
# Sequence too long (312 > 256), skipping
# Sequence too long (258 > 256), skipping
# Sequence too long (342 > 256), skipping
# Sequence too long (257 > 256), skipping
# Sequence too long (271 > 256), skipping
# Sequence too long (311 > 256), skipping
# Sequence too long (349 > 256), skipping
# Sequence too long (276 > 256), skipping
# Sequence too long (269 > 256), skipping
# Sequence too long (538 > 256), skipping
# Sequence too long (306 > 256), skipping
# Sequence too long (348 > 256), skipping
# Sequence too long (351 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (270 > 256), skipping
# Sequence too long (308 > 256), skipping
# Sequence too long (435 > 256), skipping
# Sequence too long (272 > 256), skipping
# Sequence too long (444 > 256), skipping
# Sequence too long (325 > 256), skipping
# Sequence too long (314 > 256), skipping
# Sequence too long (404 > 256), skipping
# Sequence too long (258 > 256), skipping
# Sequence too long (258 > 256), skipping
# Sequence too long (293 > 256), skipping
# Sequence too long (345 > 256), skipping
# Sequence too long (365 > 256), skipping
# Sequence too long (281 > 256), skipping
# Sequence too long (298 > 256), skipping
# Sequence too long (294 > 256), skipping
# Sequence too long (508 > 256), skipping
# Sequence too long (278 > 256), skipping
# Sequence too long (280 > 256), skipping
# Sequence too long (258 > 256), skipping
# Sequence too long (342 > 256), skipping
# Sequence too long (280 > 256), skipping
# Sequence too long (307 > 256), skipping
# Sequence too long (259 > 256), skipping
# Sequence too long (449 > 256), skipping
# Sequence too long (273 > 256), skipping
# Sequence too long (275 > 256), skipping
# Sequence too long (270 > 256), skipping
# Sequence too long (429 > 256), skipping
# Sequence too long (284 > 256), skipping
# Sequence too long (269 > 256), skipping
# Sequence too long (290 > 256), skipping
# Sequence too long (279 > 256), skipping
# Sequence too long (423 > 256), skipping
# Sequence too long (383 > 256), skipping
# Sequence too long (268 > 256), skipping
# Sequence too long (340 > 256), skipping
# Sequence too long (315 > 256), skipping
# Sequence too long (280 > 256), skipping
# Sequence too long (261 > 256), skipping
# Sequence too long (288 > 256), skipping
# Sequence too long (341 > 256), skipping
# Sequence too long (298 > 256), skipping
# Sequence too long (265 > 256), skipping
# Sequence too long (313 > 256), skipping
# Sequence too long (363 > 256), skipping
# Sequence too long (315 > 256), skipping
# Sequence too long (271 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (291 > 256), skipping
# Sequence too long (304 > 256), skipping
# Sequence too long (261 > 256), skipping
# Sequence too long (374 > 256), skipping
# Sequence too long (280 > 256), skipping
# Sequence too long (296 > 256), skipping
# Sequence too long (283 > 256), skipping
# Sequence too long (291 > 256), skipping
# Sequence too long (409 > 256), skipping
# Sequence too long (305 > 256), skipping
# Sequence too long (257 > 256), skipping
# Sequence too long (260 > 256), skipping
# Sequence too long (264 > 256), skipping
# Sequence too long (337 > 256), skipping
# Sequence too long (271 > 256), skipping
# Sequence too long (369 > 256), skipping
# Sequence too long (288 > 256), skipping
# Sequence too long (303 > 256), skipping
# Sequence too long (583 > 256), skipping
# Sequence too long (471 > 256), skipping
# Sequence too long (577 > 256), skipping
# Sequence too long (286 > 256), skipping
# Sequence too long (438 > 256), skipping
# Sequence too long (963 > 256), skipping
# Sequence too long (379 > 256), skipping
# Sequence too long (275 > 256), skipping
# Sequence too long (289 > 256), skipping
# Sequence too long (283 > 256), skipping
# Sequence too long (287 > 256), skipping
# Sequence too long (372 > 256), skipping
# Sequence too long (302 > 256), skipping
# Sequence too long (285 > 256), skipping
# Sequence too long (258 > 256), skipping
# Sequence too long (318 > 256), skipping
# Sequence too long (306 > 256), skipping
# Sequence too long (275 > 256), skipping
# Sequence too long (292 > 256), skipping
# Sequence too long (331 > 256), skipping
# Sequence too long (431 > 256), skipping
# Sequence too long (276 > 256), skipping
# Sequence too long (449 > 256), skipping
# Sequence too long (366 > 256), skipping
# Sequence too long (281 > 256), skipping
# Sequence too long (422 > 256), skipping
# Sequence too long (447 > 256), skipping
# Sequence too long (660 > 256), skipping
# Sequence too long (259 > 256), skipping
# Sequence too long (260 > 256), skipping
# Sequence too long (280 > 256), skipping
# Sequence too long (284 > 256), skipping
# Sequence too long (341 > 256), skipping
# Sequence too long (272 > 256), skipping
# Sequence too long (300 > 256), skipping
# Sequence too long (279 > 256), skipping
# Sequence too long (353 > 256), skipping
# Sequence too long (356 > 256), skipping
# Sequence too long (301 > 256), skipping
# Sequence too long (346 > 256), skipping
# Sequence too long (946 > 256), skipping
# Sequence too long (364 > 256), skipping
# Sequence too long (301 > 256), skipping
# Sequence too long (343 > 256), skipping
# Sequence too long (347 > 256), skipping
# Sequence too long (358 > 256), skipping
# Sequence too long (560 > 256), skipping
# Sequence too long (268 > 256), skipping
# Sequence too long (274 > 256), skipping
# Sequence too long (411 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (399 > 256), skipping
# Sequence too long (508 > 256), skipping
# Sequence too long (374 > 256), skipping
# Sequence too long (258 > 256), skipping
# Sequence too long (333 > 256), skipping
# Sequence too long (612 > 256), skipping
# Sequence too long (288 > 256), skipping
# Sequence too long (290 > 256), skipping
# Sequence too long (386 > 256), skipping
# Sequence too long (307 > 256), skipping
# Sequence too long (279 > 256), skipping
# Sequence too long (299 > 256), skipping
# Sequence too long (326 > 256), skipping
# Sequence too long (270 > 256), skipping
# Sequence too long (373 > 256), skipping
# Sequence too long (267 > 256), skipping
# Sequence too long (308 > 256), skipping
# Sequence too long (277 > 256), skipping
# Sequence too long (296 > 256), skipping
# Sequence too long (454 > 256), skipping
# Sequence too long (422 > 256), skipping
# Sequence too long (405 > 256), skipping
# Sequence too long (270 > 256), skipping
# Sequence too long (263 > 256), skipping
# Sequence too long (261 > 256), skipping
# Sequence too long (274 > 256), skipping
# Sequence too long (275 > 256), skipping
# Sequence too long (407 > 256), skipping
# Sequence too long (270 > 256), skipping
# Sequence too long (269 > 256), skipping
# Sequence too long (317 > 256), skipping
# Sequence too long (367 > 256), skipping
# Sequence too long (385 > 256), skipping
# Sequence too long (432 > 256), skipping
# Sequence too long (318 > 256), skipping
# Sequence too long (277 > 256), skipping
# Sequence too long (288 > 256), skipping
# Sequence too long (339 > 256), skipping
# Sequence too long (590 > 256), skipping
# Sequence too long (628 > 256), skipping
# Sequence too long (317 > 256), skipping
# Sequence too long (378 > 256), skipping
# Sequence too long (278 > 256), skipping
# Sequence too long (298 > 256), skipping
# Sequence too long (283 > 256), skipping
# Sequence too long (580 > 256), skipping
# Sequence too long (397 > 256), skipping
# Sequence too long (291 > 256), skipping
# Sequence too long (261 > 256), skipping
# Sequence too long (327 > 256), skipping
# Sequence too long (292 > 256), skipping
# Sequence too long (285 > 256), skipping
# Sequence too long (321 > 256), skipping
# Sequence too long (265 > 256), skipping
# Sequence too long (314 > 256), skipping
# Sequence too long (277 > 256), skipping
# Sequence too long (423 > 256), skipping
# Sequence too long (357 > 256), skipping
# Sequence too long (257 > 256), skipping
# Sequence too long (295 > 256), skipping
# Sequence too long (408 > 256), skipping
# Sequence too long (548 > 256), skipping
# Sequence too long (262 > 256), skipping
# Sequence too long (259 > 256), skipping
# Sequence too long (364 > 256), skipping
# Sequence too long (304 > 256), skipping
# Sequence too long (258 > 256), skipping
# Sequence too long (267 > 256), skipping
# Sequence too long (407 > 256), skipping
# Sequence too long (525 > 256), skipping
# Sequence too long (363 > 256), skipping
# Sequence too long (280 > 256), skipping
# Sequence too long (391 > 256), skipping
# Sequence too long (267 > 256), skipping
# Sequence too long (409 > 256), skipping
# Sequence too long (307 > 256), skipping
# Sequence too long (313 > 256), skipping
# Sequence too long (290 > 256), skipping
# Sequence too long (310 > 256), skipping
# Sequence too long (269 > 256), skipping
# Sequence too long (333 > 256), skipping
# Sequence too long (278 > 256), skipping
# Sequence too long (289 > 256), skipping
# Sequence too long (268 > 256), skipping
# Sequence too long (299 > 256), skipping
# Sequence too long (430 > 256), skipping
# Sequence too long (279 > 256), skipping
# Created 51001 training examples

# %%
from src.data.tokenizer import token_ids_to_text

token_ids_to_text(instruct_finetuning_dataset.input_sequences[0], tokenizer)
token_ids_to_text(instruct_finetuning_dataset.target_sequences[0], tokenizer)
# Out:
# 'Instruction:\nGive three tips for staying healthy.\n\nInput:\n\n\nResponse:\n1.Eat a balanced diet and make sure to include plenty of fruits and vegetables. \n2. Exercise regularly to keep your body active and strong. \n3. Get enough sleep and maintain a consistent sleep schedule.'
